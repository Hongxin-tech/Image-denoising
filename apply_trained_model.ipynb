# %% [markdown]
# # Import functions

# %%
# Ensure notebook be able to call functions from utils.py
import sys
sys.path.append('/kaggle/input/get-ready-to-github-conv')  # Add the directory to the system path

from utils import load_trained_model, plot_comparison_with_noisy, process_full_image  # Now import the functions

# %% [markdown]
# # Import pre-trained model

# %%
# Load the trained model
model_path = r'/kaggle/input/trained_conv_model_sigma20_snr15/pytorch/default/1/trained_lista_model_convolutional_sigma20_snr15.pth'
loaded_net = load_trained_model(model_path)
# Out:
# /kaggle/input/get-ready-to-github-conv/utils.py:595: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path)
# Model loaded successfully.

# %% [markdown]
# # Sample visualisation from train dataset

# %%
# Define paths and model
input_image_path = r'/kaggle/input/bsd500-original-greyscale-sigma20-snr15/BSD500_original_greyscale_sigma20_SNR15/BSD500_train_greyscale/118035.jpg'
noisy_image_path = r'/kaggle/input/bsd500-original-greyscale-sigma20-snr15/BSD500_original_greyscale_sigma20_SNR15/Noisy_BSD500_train_greyscale_sigma20_SNR15/118035.jpg'

# Process the noisy full image
reconstructed_image = process_full_image(input_image_path, loaded_net)
plot_comparison_with_noisy(input_image_path, noisy_image_path, reconstructed_image)

# %% [markdown]
# # Sample visualisation from validation dataset

# %%
# Define paths and model
input_image_path = r'/kaggle/input/bsd500-original-greyscale-sigma20-snr15/BSD500_original_greyscale_sigma20_SNR15/BSD500_val_greyscale/143090.jpg'
noisy_image_path = r'/kaggle/input/bsd500-original-greyscale-sigma20-snr15/BSD500_original_greyscale_sigma20_SNR15/Noisy_BSD500_val_greyscale_sigma20_SNR15/143090.jpg'

# Process the noisy full image
reconstructed_image = process_full_image(input_image_path, loaded_net)
plot_comparison_with_noisy(input_image_path, noisy_image_path, reconstructed_image)

# %% [markdown]
# # Sample visualisation from test dataset

# %%
# Define paths and model
input_image_path = r'/kaggle/input/bsd500-original-greyscale-sigma20-snr15/BSD500_original_greyscale_sigma20_SNR15/BSD500_test_greyscale/35049.jpg'
noisy_image_path = r'/kaggle/input/bsd500-original-greyscale-sigma20-snr15/BSD500_original_greyscale_sigma20_SNR15/Noisy_BSD500_test_greyscale_sigma20_SNR15/35049.jpg'

# Process the noisy full image
reconstructed_image = process_full_image(input_image_path, loaded_net)
plot_comparison_with_noisy(input_image_path, noisy_image_path, reconstructed_image)
